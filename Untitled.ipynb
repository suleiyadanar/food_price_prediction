# %% [markdown]
# # Global Food Price Data

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline
import matplotlib

# %%
df1=pd.read_csv("global_food_prices.csv")
df1.head()
# Out:
# <ipython-input-2-5eb5222765f0>:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1=pd.read_csv("global_food_prices.csv")
#    adm0_id    adm0_name  adm1_id   adm1_name  mkt_id  mkt_name  cm_id  \
# 0      1.0  Afghanistan      272  Badakhshan     266  Fayzabad     55
# 1      1.0  Afghanistan      272  Badakhshan     266  Fayzabad     55
# 2      1.0  Afghanistan      272  Badakhshan     266  Fayzabad     55
# 3      1.0  Afghanistan      272  Badakhshan     266  Fayzabad     55
# 4      1.0  Afghanistan      272  Badakhshan     266  Fayzabad     55
#
#           cm_name  cur_id cur_name  pt_id pt_name  um_id um_name  mp_month  \
# 0  Bread - Retail     0.0      AFN     15  Retail      5      KG         1
# 1  Bread - Retail     0.0      AFN     15  Retail      5      KG         2
# 2  Bread - Retail     0.0      AFN     15  Retail      5      KG         3
# 3  Bread - Retail     0.0      AFN     15  Retail      5      KG         4
# 4  Bread - Retail     0.0      AFN     15  Retail      5      KG         5
#
#    mp_year  mp_price  mp_commoditysource
# 0     2014      50.0                 NaN
# 1     2014      50.0                 NaN
# 2     2014      50.0                 NaN
# 3     2014      50.0                 NaN
# 4     2014      50.0                 NaN

# %%
#remove unnecessary columns
df2=df1.drop(['adm0_id','adm1_id','mkt_id','cur_name','cm_id','cur_id','pt_id','um_id','mp_commoditysource'],axis='columns')
df2.head()
# Out:
#      adm0_name   adm1_name  mkt_name         cm_name pt_name um_name  \
# 0  Afghanistan  Badakhshan  Fayzabad  Bread - Retail  Retail      KG
# 1  Afghanistan  Badakhshan  Fayzabad  Bread - Retail  Retail      KG
# 2  Afghanistan  Badakhshan  Fayzabad  Bread - Retail  Retail      KG
# 3  Afghanistan  Badakhshan  Fayzabad  Bread - Retail  Retail      KG
# 4  Afghanistan  Badakhshan  Fayzabad  Bread - Retail  Retail      KG
#
#    mp_month  mp_year  mp_price
# 0         1     2014      50.0
# 1         2     2014      50.0
# 2         3     2014      50.0
# 3         4     2014      50.0
# 4         5     2014      50.0

# %%
#rename the columns
df3=df2.copy()
df3.rename(columns = {'adm0_name':'country', 'adm1_name':'region', 'mkt_name':'city',
                     'cm_name':'commodity','pt_name':'sales_catagory','um_name':'unit',
                     'mp_month':'month','mp_year':'year','mp_price':'price'}, inplace = True)
df3=df3.round(2)
df3
# Out:
#              country      region        city                commodity  \
# 0        Afghanistan  Badakhshan    Fayzabad           Bread - Retail
# 1        Afghanistan  Badakhshan    Fayzabad           Bread - Retail
# 2        Afghanistan  Badakhshan    Fayzabad           Bread - Retail
# 3        Afghanistan  Badakhshan    Fayzabad           Bread - Retail
# 4        Afghanistan  Badakhshan    Fayzabad           Bread - Retail
# ...              ...         ...         ...                      ...
# 2050633     Zimbabwe    Midlands  Mbilashaba   Beans (sugar) - Retail
# 2050634     Zimbabwe    Midlands  Mbilashaba      Toothpaste - Retail
# 2050635     Zimbabwe    Midlands  Mbilashaba    Laundry soap - Retail
# 2050636     Zimbabwe    Midlands  Mbilashaba   Handwash soap - Retail
# 2050637     Zimbabwe    Midlands  Mbilashaba  Fish (kapenta) - Retail
#
#         sales_catagory    unit  month  year    price
# 0               Retail      KG      1  2014    50.00
# 1               Retail      KG      2  2014    50.00
# 2               Retail      KG      3  2014    50.00
# 3               Retail      KG      4  2014    50.00
# 4               Retail      KG      5  2014    50.00
# ...                ...     ...    ...   ...      ...
# 2050633         Retail      KG      6  2021   233.33
# 2050634         Retail  100 ML      6  2021   112.50
# 2050635         Retail      KG      6  2021   114.00
# 2050636         Retail   250 G      6  2021    59.50
# 2050637         Retail      KG      6  2021  1200.00
#
# [2050638 rows x 9 columns]

# %%
#check the number rows with null values for each column
df3.isnull().sum()
# Out:
# country                0
# region            611016
# city                   0
# commodity              0
# sales_catagory         0
# unit                   0
# month                  0
# year                   0
# price                  0
# dtype: int64

# %%
#fill the empty Regions fields with City/Town data
df3['region'].fillna(df3['city'],inplace=True)
df3.drop(['city'],axis='columns',inplace=True)
df3
# Out:
#              country      region                commodity sales_catagory  \
# 0        Afghanistan  Badakhshan           Bread - Retail         Retail
# 1        Afghanistan  Badakhshan           Bread - Retail         Retail
# 2        Afghanistan  Badakhshan           Bread - Retail         Retail
# 3        Afghanistan  Badakhshan           Bread - Retail         Retail
# 4        Afghanistan  Badakhshan           Bread - Retail         Retail
# ...              ...         ...                      ...            ...
# 2050633     Zimbabwe    Midlands   Beans (sugar) - Retail         Retail
# 2050634     Zimbabwe    Midlands      Toothpaste - Retail         Retail
# 2050635     Zimbabwe    Midlands    Laundry soap - Retail         Retail
# 2050636     Zimbabwe    Midlands   Handwash soap - Retail         Retail
# 2050637     Zimbabwe    Midlands  Fish (kapenta) - Retail         Retail
#
#            unit  month  year    price
# 0            KG      1  2014    50.00
# 1            KG      2  2014    50.00
# 2            KG      3  2014    50.00
# 3            KG      4  2014    50.00
# 4            KG      5  2014    50.00
# ...         ...    ...   ...      ...
# 2050633      KG      6  2021   233.33
# 2050634  100 ML      6  2021   112.50
# 2050635      KG      6  2021   114.00
# 2050636   250 G      6  2021    59.50
# 2050637      KG      6  2021  1200.00
#
# [2050638 rows x 8 columns]

# %%
#function to remove sales catagory tags from string
def renameCommodity(x):
    name=x.split(' -')
    return name[0]

# %%
#apply renameCommodity function on the Commodity column
df4 = df3.copy()
df4['commodity']=df4['commodity'].apply(renameCommodity)
df4.head()
# Out:
#        country      region commodity sales_catagory unit  month  year  price
# 0  Afghanistan  Badakhshan     Bread         Retail   KG      1  2014   50.0
# 1  Afghanistan  Badakhshan     Bread         Retail   KG      2  2014   50.0
# 2  Afghanistan  Badakhshan     Bread         Retail   KG      3  2014   50.0
# 3  Afghanistan  Badakhshan     Bread         Retail   KG      4  2014   50.0
# 4  Afghanistan  Badakhshan     Bread         Retail   KG      5  2014   50.0

# %%
#remove rows with years less than 2014
df5=df4[df4['year']>=2015]
df5.reset_index()
# Out:
#            index      country      region       commodity sales_catagory  \
# 0             12  Afghanistan  Badakhshan           Bread         Retail
# 1             13  Afghanistan  Badakhshan           Bread         Retail
# 2             14  Afghanistan  Badakhshan           Bread         Retail
# 3             15  Afghanistan  Badakhshan           Bread         Retail
# 4             16  Afghanistan  Badakhshan           Bread         Retail
# ...          ...          ...         ...             ...            ...
# 1441288  2050633     Zimbabwe    Midlands   Beans (sugar)         Retail
# 1441289  2050634     Zimbabwe    Midlands      Toothpaste         Retail
# 1441290  2050635     Zimbabwe    Midlands    Laundry soap         Retail
# 1441291  2050636     Zimbabwe    Midlands   Handwash soap         Retail
# 1441292  2050637     Zimbabwe    Midlands  Fish (kapenta)         Retail
#
#            unit  month  year    price
# 0            KG      1  2015    50.00
# 1            KG      2  2015    50.00
# 2            KG      3  2015    50.00
# 3            KG      6  2015    50.00
# 4            KG      7  2015    50.00
# ...         ...    ...   ...      ...
# 1441288      KG      6  2021   233.33
# 1441289  100 ML      6  2021   112.50
# 1441290      KG      6  2021   114.00
# 1441291   250 G      6  2021    59.50
# 1441292      KG      6  2021  1200.00
#
# [1441293 rows x 9 columns]

# %%
#check if the regions have enough data
df6=df5.copy()
df6.region=df6.region.apply(lambda x:x.strip())
region_stats=df6.groupby('region')['region'].agg('count').sort_values(ascending=False)
region_stats
# Out:
# region
# Yobe               15671
# Borno              13965
# Homs               13419
# Aleppo             12573
# South/Amajyepfo    11858
#                    ...
# Oumhadjer              6
# Amdjarass              3
# Granada                2
# Leon                   2
# Faya                   2
# Name: region, Length: 1303, dtype: int64

# %%
#remove regions with less than 84 months worth of data
region_stats_less_84=region_stats[region_stats<84]
df6.region=df6.region.apply(lambda x:"" if x in region_stats_less_84 else x)
df7=df6[df6['region']!=""]
df7
# Out:
#              country      region       commodity sales_catagory    unit  \
# 12       Afghanistan  Badakhshan           Bread         Retail      KG
# 13       Afghanistan  Badakhshan           Bread         Retail      KG
# 14       Afghanistan  Badakhshan           Bread         Retail      KG
# 15       Afghanistan  Badakhshan           Bread         Retail      KG
# 16       Afghanistan  Badakhshan           Bread         Retail      KG
# ...              ...         ...             ...            ...     ...
# 2050633     Zimbabwe    Midlands   Beans (sugar)         Retail      KG
# 2050634     Zimbabwe    Midlands      Toothpaste         Retail  100 ML
# 2050635     Zimbabwe    Midlands    Laundry soap         Retail      KG
# 2050636     Zimbabwe    Midlands   Handwash soap         Retail   250 G
# 2050637     Zimbabwe    Midlands  Fish (kapenta)         Retail      KG
#
#          month  year    price
# 12           1  2015    50.00
# 13           2  2015    50.00
# 14           3  2015    50.00
# 15           6  2015    50.00
# 16           7  2015    50.00
# ...        ...   ...      ...
# 2050633      6  2021   233.33
# 2050634      6  2021   112.50
# 2050635      6  2021   114.00
# 2050636      6  2021    59.50
# 2050637      6  2021  1200.00
#
# [1437676 rows x 8 columns]

# %%
country_stats=df7.groupby('country')['country'].agg('count').sort_values(ascending=False)
country_stats
# Out:
# country
# Syrian Arab Republic    109104
# Bassas da India          96048
# Indonesia                71394
# Philippines              63052
# Burundi                  57286
#                          ...
# Moldova Republic of        147
# Gabon                      120
# Bhutan                     115
# Costa Rica                  39
# Venezuela                    6
# Name: country, Length: 93, dtype: int64

# %%
#check if the data of commodities is balanced
commodity_stats=df7.groupby('commodity')['commodity'].agg('count').sort_values(ascending=False)
commodity_stats.describe()
df7
# Out:
#              country      region       commodity sales_catagory    unit  \
# 12       Afghanistan  Badakhshan           Bread         Retail      KG
# 13       Afghanistan  Badakhshan           Bread         Retail      KG
# 14       Afghanistan  Badakhshan           Bread         Retail      KG
# 15       Afghanistan  Badakhshan           Bread         Retail      KG
# 16       Afghanistan  Badakhshan           Bread         Retail      KG
# ...              ...         ...             ...            ...     ...
# 2050633     Zimbabwe    Midlands   Beans (sugar)         Retail      KG
# 2050634     Zimbabwe    Midlands      Toothpaste         Retail  100 ML
# 2050635     Zimbabwe    Midlands    Laundry soap         Retail      KG
# 2050636     Zimbabwe    Midlands   Handwash soap         Retail   250 G
# 2050637     Zimbabwe    Midlands  Fish (kapenta)         Retail      KG
#
#          month  year    price
# 12           1  2015    50.00
# 13           2  2015    50.00
# 14           3  2015    50.00
# 15           6  2015    50.00
# 16           7  2015    50.00
# ...        ...   ...      ...
# 2050633      6  2021   233.33
# 2050634      6  2021   112.50
# 2050635      6  2021   114.00
# 2050636      6  2021    59.50
# 2050637      6  2021  1200.00
#
# [1437676 rows x 8 columns]

# %%
df8=df7.copy()
commodity_stats_less=commodity_stats[commodity_stats<2000]
df8.commodity=df8.commodity.apply(lambda x:"" if x in commodity_stats_less else x)
df8=df8[df8['commodity']!=""]
df8
# Out:
#              country      region      commodity sales_catagory    unit  month  \
# 12       Afghanistan  Badakhshan          Bread         Retail      KG      1
# 13       Afghanistan  Badakhshan          Bread         Retail      KG      2
# 14       Afghanistan  Badakhshan          Bread         Retail      KG      3
# 15       Afghanistan  Badakhshan          Bread         Retail      KG      6
# 16       Afghanistan  Badakhshan          Bread         Retail      KG      7
# ...              ...         ...            ...            ...     ...    ...
# 2050631     Zimbabwe    Midlands          Sugar         Retail      KG      6
# 2050632     Zimbabwe    Midlands           Salt         Retail      KG      6
# 2050634     Zimbabwe    Midlands     Toothpaste         Retail  100 ML      6
# 2050635     Zimbabwe    Midlands   Laundry soap         Retail      KG      6
# 2050636     Zimbabwe    Midlands  Handwash soap         Retail   250 G      6
#
#          year   price
# 12       2015   50.00
# 13       2015   50.00
# 14       2015   50.00
# 15       2015   50.00
# 16       2015   50.00
# ...       ...     ...
# 2050631  2021  118.38
# 2050632  2021   71.00
# 2050634  2021  112.50
# 2050635  2021  114.00
# 2050636  2021   59.50
#
# [1149522 rows x 8 columns]

# %%
#mean price of each commodity per year for each region
df9=df8.groupby(['country','commodity','sales_catagory','year','unit'],as_index=False)['price'].mean().round(2)
df9.head(50)
# Out:
#         country                                      commodity sales_catagory  \
# 0   Afghanistan                                          Bread         Retail
# 1   Afghanistan                                          Bread         Retail
# 2   Afghanistan                                          Bread         Retail
# 3   Afghanistan                                          Bread         Retail
# 4   Afghanistan                                          Bread         Retail
# 5   Afghanistan                                          Bread         Retail
# 6   Afghanistan                                          Bread         Retail
# 7   Afghanistan                                  Exchange rate         Retail
# 8   Afghanistan                                  Exchange rate         Retail
# 9   Afghanistan                                  Exchange rate         Retail
# 10  Afghanistan                                  Exchange rate         Retail
# 11  Afghanistan                                  Exchange rate         Retail
# 12  Afghanistan                                  Exchange rate         Retail
# 13  Afghanistan                                  Exchange rate         Retail
# 14  Afghanistan                                  Fuel (diesel)         Retail
# 15  Afghanistan                                  Fuel (diesel)         Retail
# 16  Afghanistan                                  Fuel (diesel)         Retail
# 17  Afghanistan                                  Fuel (diesel)         Retail
# 18  Afghanistan                                  Fuel (diesel)         Retail
# 19  Afghanistan                                  Fuel (diesel)         Retail
# 20  Afghanistan                                  Fuel (diesel)         Retail
# 21  Afghanistan                                         Pulses         Retail
# 22  Afghanistan                                         Pulses         Retail
# 23  Afghanistan                            Rice (high quality)         Retail
# 24  Afghanistan                            Rice (high quality)         Retail
# 25  Afghanistan                             Rice (low quality)         Retail
# 26  Afghanistan                             Rice (low quality)         Retail
# 27  Afghanistan                             Rice (low quality)         Retail
# 28  Afghanistan                             Rice (low quality)         Retail
# 29  Afghanistan                             Rice (low quality)         Retail
# 30  Afghanistan                             Rice (low quality)         Retail
# 31  Afghanistan                             Rice (low quality)         Retail
# 32  Afghanistan                                           Salt         Retail
# 33  Afghanistan                                           Salt         Retail
# 34  Afghanistan                                          Sugar         Retail
# 35  Afghanistan                                          Sugar         Retail
# 36  Afghanistan  Wage (non-qualified labour, non-agricultural)         Retail
# 37  Afghanistan  Wage (non-qualified labour, non-agricultural)         Retail
# 38  Afghanistan  Wage (non-qualified labour, non-agricultural)         Retail
# 39  Afghanistan  Wage (non-qualified labour, non-agricultural)         Retail
# 40  Afghanistan  Wage (non-qualified labour, non-agricultural)         Retail
# 41  Afghanistan  Wage (non-qualified labour, non-agricultural)         Retail
# 42  Afghanistan  Wage (non-qualified labour, non-agricultural)         Retail
# 43  Afghanistan                        Wage (qualified labour)         Retail
# 44  Afghanistan                        Wage (qualified labour)         Retail
# 45  Afghanistan                        Wage (qualified labour)         Retail
# 46  Afghanistan                        Wage (qualified labour)         Retail
# 47  Afghanistan                        Wage (qualified labour)         Retail
# 48  Afghanistan                        Wage (qualified labour)         Retail
# 49  Afghanistan                        Wage (qualified labour)         Retail
#
#     year     unit   price
# 0   2015       KG   44.39
# 1   2016       KG   44.70
# 2   2017       KG   44.45
# 3   2018       KG   44.29
# 4   2019       KG   44.51
# 5   2020       KG   50.88
# 6   2021       KG   52.53
# 7   2015  USD/LCU   61.24
# 8   2016  USD/LCU   67.70
# 9   2017  USD/LCU   68.02
# 10  2018  USD/LCU   72.32
# 11  2019  USD/LCU   77.83
# 12  2020  USD/LCU   76.94
# 13  2021  USD/LCU   78.04
# 14  2015        L   43.96
# 15  2016        L   37.14
# 16  2017        L   43.59
# 17  2018        L   48.70
# 18  2019        L   49.59
# 19  2020        L   37.73
# 20  2021        L   46.88
# 21  2020       KG   92.84
# 22  2021       KG   91.93
# 23  2020       KG   87.35
# 24  2021       KG   88.03
# 25  2015       KG   39.62
# 26  2016       KG   41.44
# 27  2017       KG   44.24
# 28  2018       KG   46.09
# 29  2019       KG   45.87
# 30  2020       KG   48.95
# 31  2021       KG   49.70
# 32  2020       KG   12.46
# 33  2021       KG   13.43
# 34  2020       KG   49.91
# 35  2021       KG   50.61
# 36  2015      Day  271.57
# 37  2016      Day  288.52
# 38  2017      Day  318.49
# 39  2018      Day  301.17
# 40  2019      Day  309.74
# 41  2020      Day  304.92
# 42  2021      Day  302.54
# 43  2015      Day  640.36
# 44  2016      Day  638.92
# 45  2017      Day  686.20
# 46  2018      Day  690.62
# 47  2019      Day  714.19
# 48  2020      Day  674.12
# 49  2021      Day  645.96

# %%
def remove_price_outliers(df):
    df_out=pd.DataFrame()
    for key,subdf in df.groupby(['country','commodity'],as_index=False):
        m = np.mean(subdf.price)
        st=np.std(subdf.price)
        reduced_df=subdf[(subdf.price>(m-(st*2)))&(subdf.price<=(m+(st/2)))]
        df_out=pd.concat([df_out,reduced_df],ignore_index=True)
    return df_out
df10=remove_price_outliers(df9)
# Out:
# country                Cameroon
# commodity         Beans (niebe)
# sales_catagory        Wholesale
# year                       2016
# unit                     100 KG
# price                  28266.17
# Name: 700, dtype: object

# %%
# def remove_less(df):
#     df_out=pd.DataFrame()
#     for key,subdf in df.groupby(['region','commodity'],as_index=False):
#             subdf.value_counts()
#             if(subdf.value_counts()<5):
#                 reduced_df=df.drop(key)
#                 df_out=pd.concat([df_out,reduced_df],ignore_index=True)
#     return df_out
# df11=remove_less(df10)
# df11
